# %% [markdown]
# <a href="https://colab.research.google.com/github/UtharaS123/Feature-Selection/blob/main/feature_selection_optuna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature Selection with Optuna

# %%
# !pip install -q optuna

# %% [markdown]
# ## Requirements

# %%
import pandas as pd

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report
from sklearn.model_selection import StratifiedKFold

import optuna
from optuna.samplers import TPESampler

from sklearn.feature_selection import SelectKBest, chi2
from sklearn.feature_selection import SequentialFeatureSelector

# %%
class FeatureSelectionOptuna:
    """
    This class implements feature selection using Optuna optimization framework.

    Parameters:

    - model (object): The predictive model to evaluate; this should be any object that implements fit() and predict() methods.
    - loss_fn (function): The loss function to use for evaluating the model performance. This function should take the true labels and the
                          predictions as inputs and return a loss value.
    - features (list of str): A list containing the names of all possible features that can be selected for the model.
    - X (DataFrame): The complete set of feature data (pandas DataFrame) from which subsets will be selected for training the model.
    - y (Series): The target variable associated with the X data (pandas Series).
    - splits (list of tuples): A list of tuples where each tuple contains two elements, the train indices and the validation indices.
    - penalty (float, optional): A factor used to penalize the objective function based on the number of features used.
    """

    def __init__(self,
                 model,
                 loss_fn,
                 features,
                 X,
                 y,
                 splits,
                 penalty=0):

        self.model = model
        self.loss_fn = loss_fn
        self.features = features
        self.X = X
        self.y = y
        self.splits = splits
        self.penalty = penalty

    def __call__(self,
                 trial: optuna.trial.Trial):

        # Select True / False for each feature
        selected_features = [trial.suggest_categorical(name, [True, False]) for name in self.features]

        # List with names of selected features
        selected_feature_names = [name for name, selected in zip(self.features, selected_features) if selected]

        # Optional: adds a penalty for the amount of features used
        n_used = len(selected_feature_names)
        total_penalty = n_used * self.penalty

        loss = 0

        for split in self.splits:
          train_idx = split[0]
          valid_idx = split[1]

          X_train = self.X.iloc[train_idx].copy()
          y_train = self.y.iloc[train_idx].copy()
          X_valid = self.X.iloc[valid_idx].copy()
          y_valid = self.y.iloc[valid_idx].copy()

          X_train_selected = X_train[selected_feature_names].copy()
          X_valid_selected = X_valid[selected_feature_names].copy()

          # Train model, get predictions and accumulate loss
          self.model.fit(X_train_selected, y_train)
          pred = self.model.predict(X_valid_selected)

          loss += self.loss_fn(y_valid, pred)

        # Take the average loss across all splits
        loss /= len(self.splits)

        # Add the penalty to the loss
        loss += total_penalty

        return loss

# %% [markdown]
# ## Data

# %%
SEED = 32

# Load data
filename = "train.csv" # train.csv from https://www.kaggle.com/datasets/iabhishekofficial/mobile-price-classification

df = pd.read_csv(filename)

# Train - test split
df_train, df_test = train_test_split(df, test_size=0.2, stratify=df.iloc[:,-1], random_state=SEED)
df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# The last column is the target variable
X_train = df_train.iloc[:,0:20]
y_train = df_train.iloc[:,-1]
X_test = df_test.iloc[:,0:20]
y_test = df_test.iloc[:,-1]

# Stratified kfold over the train set for cross validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)
splits = list(skf.split(X_train, y_train))

# %% [markdown]
# ## All Features
#
# We fit the RSF using all features as benchmark

# %%
model = RandomForestClassifier(random_state=SEED)
model.fit(X_train,y_train)
preds = model.predict(X_test)

print(classification_report(y_test, preds))
print(f"Global F1: {f1_score(y_test, preds, average='weighted')}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.93      0.92       100
#            1       0.80      0.78      0.79       100
#            2       0.83      0.82      0.82       100
#            3       0.95      0.95      0.95       100
#
#     accuracy                           0.87       400
#    macro avg       0.87      0.87      0.87       400
# weighted avg       0.87      0.87      0.87       400
#
# Global F1: 0.8695638871323328

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ### Optuna
#
# We conduct an Optuna study for 100 trials and retrieve the best one

# %%
def loss_fn(y_true, y_pred):
  """
  Returns the negative F1 score, to be treated as a loss function.
  """
  res = -f1_score(y_true, y_pred, average='weighted')
  return res

features = list(X_train.columns)

model = RandomForestClassifier(random_state=SEED)

sampler = TPESampler(seed = SEED)
study = optuna.create_study(direction="minimize",sampler=sampler)

# We first try the model using all features
default_features = {ft: True for ft in features}
study.enqueue_trial(default_features)

study.optimize(FeatureSelectionOptuna(
                         model=model,
                         loss_fn=loss_fn,
                         features=features,
                         X=X_train,
                         y=y_train,
                         splits=splits,
                         penalty = 1e-4,
                         ), n_trials=100)
# Out:
# [I 2024-05-07 13:27:31,859] A new study created in memory with name: no-name-79f43521-f2a5-448d-8082-43c5155c177f
# [I 2024-05-07 13:27:34,317] Trial 0 finished with value: -0.8638106948596054 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': True, 'n_cores': True, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:36,383] Trial 1 finished with value: -0.28782853702378036 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': False, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': True, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': False, 'ram': False, 'sc_h': False, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': True}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:38,388] Trial 2 finished with value: -0.7786332178750087 and parameters: {'battery_power': False, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': True, 'm_dep': True, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': True, 'px_width': False, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': False, 'wifi': False}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:40,132] Trial 3 finished with value: -0.2701845753639059 and parameters: {'battery_power': False, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': False, 'px_width': True, 'ram': False, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:43,395] Trial 4 finished with value: -0.2904194991742043 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': False, 'dual_sim': False, 'fc': False, 'four_g': False, 'int_memory': True, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': True, 'px_height': False, 'px_width': False, 'ram': False, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': True}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:46,465] Trial 5 finished with value: -0.24445982443299374 and parameters: {'battery_power': False, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': False, 'px_width': False, 'ram': False, 'sc_h': True, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': True}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:48,487] Trial 6 finished with value: -0.24108306170538626 and parameters: {'battery_power': False, 'blue': False, 'clock_speed': True, 'dual_sim': True, 'fc': False, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': True, 'pc': False, 'px_height': False, 'px_width': False, 'ram': False, 'sc_h': True, 'sc_w': False, 'talk_time': False, 'three_g': True, 'touch_screen': False, 'wifi': True}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:50,451] Trial 7 finished with value: -0.2945778022883766 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': True, 'dual_sim': True, 'fc': False, 'four_g': True, 'int_memory': False, 'm_dep': True, 'mobile_wt': True, 'n_cores': True, 'pc': True, 'px_height': False, 'px_width': False, 'ram': False, 'sc_h': True, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': True, 'wifi': False}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:52,130] Trial 8 finished with value: -0.7161204166379002 and parameters: {'battery_power': False, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': False, 'px_width': False, 'ram': True, 'sc_h': True, 'sc_w': False, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': False}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:54,011] Trial 9 finished with value: -0.28700332094856695 and parameters: {'battery_power': False, 'blue': False, 'clock_speed': False, 'dual_sim': False, 'fc': False, 'four_g': True, 'int_memory': True, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': True, 'px_height': False, 'px_width': True, 'ram': False, 'sc_h': True, 'sc_w': False, 'talk_time': False, 'three_g': True, 'touch_screen': True, 'wifi': False}. Best is trial 0 with value: -0.8638106948596054.
# [I 2024-05-07 13:27:55,904] Trial 10 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:27:58,007] Trial 11 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:00,807] Trial 12 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:04,590] Trial 13 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:07,035] Trial 14 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:09,311] Trial 15 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:12,204] Trial 16 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:19,547] Trial 17 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:23,007] Trial 18 finished with value: -0.8765422905971675 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': True, 'wifi': False}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:25,474] Trial 19 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:28,984] Trial 20 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:33,556] Trial 21 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:36,128] Trial 22 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:38,342] Trial 23 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:40,310] Trial 24 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:42,877] Trial 25 finished with value: -0.8882297523153013 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': True, 'm_dep': True, 'mobile_wt': False, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': True, 'three_g': True, 'touch_screen': True, 'wifi': True}. Best is trial 10 with value: -0.8882297523153013.
# [I 2024-05-07 13:28:45,483] Trial 26 finished with value: -0.9058518343455045 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 26 with value: -0.9058518343455045.
# [I 2024-05-07 13:28:47,320] Trial 27 finished with value: -0.9058518343455045 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 26 with value: -0.9058518343455045.
# [I 2024-05-07 13:28:49,218] Trial 28 finished with value: -0.9058518343455045 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 26 with value: -0.9058518343455045.
# [I 2024-05-07 13:28:50,967] Trial 29 finished with value: -0.9058518343455045 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 26 with value: -0.9058518343455045.
# [I 2024-05-07 13:28:52,866] Trial 30 finished with value: -0.9058518343455045 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 26 with value: -0.9058518343455045.
# [I 2024-05-07 13:28:54,671] Trial 31 finished with value: -0.9058518343455045 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 26 with value: -0.9058518343455045.
# [I 2024-05-07 13:28:57,173] Trial 32 finished with value: -0.9058518343455045 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 26 with value: -0.9058518343455045.
# [I 2024-05-07 13:28:59,756] Trial 33 finished with value: -0.9058518343455045 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': True, 'int_memory': False, 'm_dep': False, 'mobile_wt': False, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': True, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 26 with value: -0.9058518343455045.
# [I 2024-05-07 13:29:01,581] Trial 34 finished with value: -0.911682100107814 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:03,402] Trial 35 finished with value: -0.7841813458131511 and parameters: {'battery_power': False, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:05,554] Trial 36 finished with value: -0.29217655286564476 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': True, 'px_width': False, 'ram': False, 'sc_h': False, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:07,545] Trial 37 finished with value: -0.7841813458131511 and parameters: {'battery_power': False, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:09,682] Trial 38 finished with value: -0.287304012392604 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': False, 'dual_sim': True, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': False, 'px_width': False, 'ram': False, 'sc_h': False, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:12,508] Trial 39 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:14,516] Trial 40 finished with value: -0.23161995013548436 and parameters: {'battery_power': False, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': False, 'px_width': False, 'ram': False, 'sc_h': False, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:16,661] Trial 41 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:18,735] Trial 42 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:20,927] Trial 43 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:23,012] Trial 44 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:25,209] Trial 45 finished with value: -0.8656231538593978 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': False, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:27,642] Trial 46 finished with value: -0.7775515204176746 and parameters: {'battery_power': False, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': True, 'px_width': False, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:29,729] Trial 47 finished with value: -0.27272506417895503 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': False, 'sc_h': False, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:31,512] Trial 48 finished with value: -0.8656231538593978 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': False, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:33,390] Trial 49 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:35,445] Trial 50 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:37,304] Trial 51 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:39,937] Trial 52 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:42,332] Trial 53 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:44,254] Trial 54 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:46,154] Trial 55 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:48,197] Trial 56 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:50,260] Trial 57 finished with value: -0.26344501628558603 and parameters: {'battery_power': False, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': True, 'px_width': False, 'ram': False, 'sc_h': False, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:52,258] Trial 58 finished with value: -0.8878698537510427 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:54,755] Trial 59 finished with value: -0.8656231538593978 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': False, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:57,169] Trial 60 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:29:59,189] Trial 61 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:01,152] Trial 62 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:03,347] Trial 63 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:05,459] Trial 64 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:08,186] Trial 65 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:10,414] Trial 66 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:12,319] Trial 67 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:14,195] Trial 68 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:16,245] Trial 69 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:18,389] Trial 70 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:21,447] Trial 71 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:24,016] Trial 72 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:25,927] Trial 73 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:27,809] Trial 74 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:29,677] Trial 75 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:31,581] Trial 76 finished with value: -0.7775515204176746 and parameters: {'battery_power': False, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': True, 'px_width': False, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:33,904] Trial 77 finished with value: -0.27272506417895503 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': False, 'sc_h': False, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:36,388] Trial 78 finished with value: -0.8656231538593978 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': False, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:38,532] Trial 79 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:42,307] Trial 80 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:45,812] Trial 81 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:48,450] Trial 82 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:51,193] Trial 83 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:54,019] Trial 84 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:56,516] Trial 85 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:30:58,540] Trial 86 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:00,510] Trial 87 finished with value: -0.26344501628558603 and parameters: {'battery_power': False, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': True, 'pc': False, 'px_height': True, 'px_width': False, 'ram': False, 'sc_h': False, 'sc_w': False, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:03,004] Trial 88 finished with value: -0.8971432941654774 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': False, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': True}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:05,556] Trial 89 finished with value: -0.8661832667028617 and parameters: {'battery_power': True, 'blue': False, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': True, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': False, 'px_width': True, 'ram': True, 'sc_h': True, 'sc_w': True, 'talk_time': False, 'three_g': True, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:07,393] Trial 90 finished with value: -0.8927209718040345 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': True, 'mobile_wt': True, 'n_cores': False, 'pc': True, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': True, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:09,394] Trial 91 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:11,319] Trial 92 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:13,427] Trial 93 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:15,914] Trial 94 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:18,872] Trial 95 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:21,015] Trial 96 finished with value: -0.9079817381959971 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': True, 'dual_sim': False, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:23,062] Trial 97 finished with value: -0.911682100107814 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:25,135] Trial 98 finished with value: -0.911682100107814 and parameters: {'battery_power': True, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': False}. Best is trial 34 with value: -0.911682100107814.
# [I 2024-05-07 13:31:26,918] Trial 99 finished with value: -0.7916181609522877 and parameters: {'battery_power': False, 'blue': True, 'clock_speed': False, 'dual_sim': True, 'fc': True, 'four_g': False, 'int_memory': False, 'm_dep': False, 'mobile_wt': True, 'n_cores': False, 'pc': False, 'px_height': True, 'px_width': True, 'ram': True, 'sc_h': False, 'sc_w': True, 'talk_time': False, 'three_g': False, 'touch_screen': False, 'wifi': True}. Best is trial 34 with value: -0.911682100107814.

# %%
selected_features = study.best_params
selected_features = [ft for ft in selected_features.keys() if selected_features[ft]]
selected_features
# Out:
# ['battery_power',
#  'blue',
#  'dual_sim',
#  'fc',
#  'mobile_wt',
#  'px_height',
#  'px_width',
#  'ram',
#  'sc_w']

# %%
# We train the RSF using only the selected features

X_train_selected = X_train[selected_features].copy()
X_test_selected = X_test[selected_features].copy()

model = RandomForestClassifier(random_state=SEED)
model.fit(X_train_selected,y_train)
preds = model.predict(X_test_selected)

print(classification_report(y_test, preds))
print(f"Global F1: {f1_score(y_test, preds, average='weighted')}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       100
#            1       0.84      0.83      0.83       100
#            2       0.84      0.84      0.84       100
#            3       0.94      0.92      0.93       100
#
#     accuracy                           0.88       400
#    macro avg       0.88      0.88      0.88       400
# weighted avg       0.88      0.88      0.88       400
#
# Global F1: 0.8823930394871305

# %% [markdown]
# ### Chi-Squared
#
# Filter method retrieving the 10 features that achieve the highest Chi Squared test. Uses `SelectKBest` from scikit learn.

# %%
skb = SelectKBest(score_func=chi2, k=10)
skb.fit(X_train,y_train)

scores = pd.DataFrame(skb.scores_)
cols = pd.DataFrame(X_train.columns)
featureScores = pd.concat([cols,scores],axis=1)
featureScores.columns = ['feature','score']
featureScores.nlargest(10, 'score')
# Out:
#           feature          score
# 13            ram  750616.905156
# 11      px_height   11671.298340
# 0   battery_power   10905.619087
# 12       px_width    7397.706340
# 8       mobile_wt     109.440113
# 6      int_memory      62.487665
# 15           sc_w      19.316377
# 14           sc_h      11.805343
# 16      talk_time      11.401764
# 10             pc      10.865630

# %%
selected_features = featureScores.nlargest(10,'score').feature.values

X_train_selected = df_train[selected_features].copy()
X_test_selected = df_test[selected_features].copy()

model = RandomForestClassifier(random_state=SEED)
model.fit(X_train_selected,y_train)
preds = model.predict(X_test_selected)

print(classification_report(y_test, preds))
print(f"Global F1: {f1_score(y_test, preds, average='weighted')}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       100
#            1       0.83      0.85      0.84       100
#            2       0.84      0.83      0.83       100
#            3       0.95      0.93      0.94       100
#
#     accuracy                           0.89       400
#    macro avg       0.89      0.89      0.89       400
# weighted avg       0.89      0.89      0.89       400
#
# Global F1: 0.8877508043276541

# %% [markdown]
# ### Forward Search
#
# Wrapper method using `SequentialFeatureSelector` from scikit-learn. At each step, it adds the feature that yields the highest performance increase.

# %%
model = RandomForestClassifier(random_state=SEED)
sfs = SequentialFeatureSelector(model, n_features_to_select=10, cv=splits)
sfs.fit(X_train, y_train);

selected_features = list(X_train.columns[sfs.get_support()])
print(selected_features)
# Out:
# ['battery_power', 'blue', 'fc', 'mobile_wt', 'px_height', 'px_width', 'ram', 'talk_time', 'three_g', 'touch_screen']

# %%
X_train_selected = df_train[selected_features].copy()
X_test_selected = df_test[selected_features].copy()

model = RandomForestClassifier(random_state=SEED)
model.fit(X_train_selected,y_train)
preds = model.predict(X_test_selected)

print(classification_report(y_test, preds))
print(f"Global F1: {f1_score(y_test, preds, average='weighted')}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93       100
#            1       0.84      0.83      0.83       100
#            2       0.83      0.83      0.83       100
#            3       0.93      0.92      0.92       100
#
#     accuracy                           0.88       400
#    macro avg       0.88      0.88      0.88       400
# weighted avg       0.88      0.88      0.88       400
#
# Global F1: 0.8798717597890443

# %% [markdown]
# ### Feature Importance
#
# Uses feature importance estimated by the RSF to select the 10 most important features.

# %%
model = RandomForestClassifier(random_state=SEED)
model.fit(X_train,y_train)

importance = pd.DataFrame({'feature':X_train.columns, 'importance':model.feature_importances_})
importance.nlargest(10, 'importance')
# Out:
#           feature  importance
# 13            ram    0.483098
# 0   battery_power    0.076937
# 12       px_width    0.058843
# 11      px_height    0.058158
# 8       mobile_wt    0.039197
# 6      int_memory    0.033332
# 16      talk_time    0.030169
# 10             pc    0.028992
# 15           sc_w    0.028824
# 14           sc_h    0.027064

# %%
selected_features = importance.nlargest(10,'importance').feature.values

X_train_selected = df_train[selected_features].copy()
X_test_selected = df_test[selected_features].copy()

model = RandomForestClassifier(random_state=SEED)
model.fit(X_train_selected,y_train)
preds = model.predict(X_test_selected)

print(classification_report(y_test, preds))
print(f"Global F1: {f1_score(y_test, preds, average='weighted')}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94       100
#            1       0.82      0.84      0.83       100
#            2       0.82      0.83      0.83       100
#            3       0.97      0.91      0.94       100
#
#     accuracy                           0.88       400
#    macro avg       0.88      0.88      0.88       400
# weighted avg       0.88      0.88      0.88       400
#
# Global F1: 0.8830488107413922
